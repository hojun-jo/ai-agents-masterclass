# %%
from autogen_agentchat.teams import SelectorGroupChat
from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.ui import Console
from dotenv import load_dotenv
from tools import web_search_tool, save_report_to_md

load_dotenv()
# Out:
# True

# %%
model_client = OpenAIChatCompletionClient(
  model="gpt-4.1-nano"
)

# %%
research_planner = AssistantAgent(
    "research_planner",
    description="A strategic research coordinator that breaks down complex questions into research subtasks",
    model_client=model_client,
    system_message="""You are a research planning specialist. Your job is to create a focused research plan.

For each research question, create a FOCUSED research plan with:

1. **Core Topics**: 2-3 main areas to investigate
2. **Search Queries**: Create 3-5 specific search queries covering:
   - Latest developments and news
   - Key statistics or data
   - Expert analysis or studies
   - Future outlook

Keep the plan focused and achievable. Quality over quantity.""",
)

research_agent = AssistantAgent(
    "research_agent",
    description="A web research specialist that searches and extracts content",
    tools=[web_search_tool],
    model_client=model_client,
    system_message="""You are a web research specialist. Your job is to conduct focused searches based on the research plan.

RESEARCH STRATEGY:
1. **Execute 3-5 searches** from the research plan
2. **Extract key information** from the results:
   - Main facts and statistics
   - Recent developments
   - Expert opinions
   - Important context

3. **Quality focus**:
   - Prioritize authoritative sources
   - Look for recent information (within 2 years)
   - Note diverse perspectives

After completing the searches from the plan, summarize what you found. Your goal is to gather 5-10 quality sources.""",
)

research_analyst = AssistantAgent(
    "research_analyst",
    description="An expert analyst that creates research reports",
    model_client=model_client,
    system_message="""You are a research analyst. Create a comprehensive report from the gathered research.

CREATE A RESEARCH REPORT with:

## Executive Summary
- Key findings and conclusions
- Main insights

## Background & Current State
- Current landscape
- Recent developments
- Key statistics and data

## Analysis & Insights
- Main trends
- Different perspectives
- Expert opinions

## Future Outlook
- Emerging trends
- Predictions
- Implications

## Sources
- List all sources used

Write a clear, well-structured report based on the research gathered. End with "REPORT_COMPLETE" when finished.""",
)

quality_reviewer = AssistantAgent(
    "quality_reviewer",
    description="A quality assurance specialist that evaluates research completeness and accuracy",
    tools=[save_report_to_md],
    model_client=model_client,
    system_message="""You are a quality reviewer. Your job is to check if the research analyst has produced a complete research report.

Look for:
- A comprehensive research report from the research analyst that ends with "REPORT_COMPLETE"
- The research question is fully answered
- Sources are cited and reliable
- The report includes summary, key information, analysis, and sources

When you see a complete research report that ends with "REPORT_COMPLETE":
1. First, use the save_report_to_md tool to save the report to report.md
2. Then say: "The research is complete. The report has been saved to report.md. Please review the report and let me know if you approve it or need additional research."

If the research analyst has NOT yet created a complete report, tell them to create one now.""",
)

research_enhancer = AssistantAgent(
    "research_enhancer",
    description="A specialist that identifies critical gaps only",
    model_client=model_client,
    system_message="""You are a research enhancement specialist. Your job is to identify ONLY CRITICAL gaps.

Review the research and ONLY suggest additional searches if there are MAJOR gaps like:
- Completely missing recent developments (last 6 months)
- No statistics or data at all
- Missing a crucial perspective that was specifically asked for

If the research covers the basics reasonably well, say: "The research is sufficient to proceed with the report."

Only suggest 1-2 additional searches if absolutely necessary. We prioritize getting a good report done rather than perfect coverage.""",
)

user_proxy = UserProxyAgent(
    "user_proxy",
    description="Human reviewer who can request additional research or approve final results",
    input_func=input,
)

# %%
selector_prompt = """
Choose the best agent for the current task based on the conversation history:

{roles}

Current conversation:
{history}

Available agents:
- research_planner: Plan the research approach (ONLY at the start)
- research_agent: Search for and extract content from web sources (after planning)
- research_enhancer: Identify CRITICAL gaps only (use sparingly)
- research_analyst: Write the final research report
- quality_reviewer: Check if a complete report exists
- user_proxy: Ask the human for feedback

WORKFLOW:
1. If no planning done yet → select research_planner
2. If planning done but no research → select research_agent  
3. After research_agent completes initial searches → select research_enhancer ONCE
4. If enhancer says "sufficient to proceed" → select research_analyst
5. If enhancer suggests critical searches → select research_agent ONCE more then research_analyst
6. If research_analyst said "REPORT_COMPLETE" → select quality_reviewer
7. If quality_reviewer asked for user feedback → select user_proxy

IMPORTANT: After research_agent has searched 2 times maximum, proceed to research_analyst regardless.

Pick the agent that should work next based on this workflow."""

# %%
text_termination = TextMentionTermination("APPROVED")
max_message_termination = MaxMessageTermination(max_messages=50)
termination_condition = text_termination | max_message_termination

team = SelectorGroupChat(
    participants=[
        research_agent,
        research_analyst,
        research_enhancer,
        research_planner,
        quality_reviewer,
        user_proxy,
    ],
    selector_prompt=selector_prompt,
    model_client=model_client,
    # allow_repeated_speaker=True,
    termination_condition=termination_condition,
)

# %%
await Console(
    team.run_stream(task="Research about the new development in Nuclear Energy"),
)
# Out:
# ---------- TextMessage (user) ----------
# Research about the new development in Nuclear Energy
# ---------- TextMessage (research_planner) ----------
# **Research Plan: New Developments in Nuclear Energy**
#
# **1. Core Topics:**
# - Advanced Nuclear Reactor Technologies (e.g., small modular reactors, fast reactors)
# - Innovations in Nuclear Fuel and Waste Management
# - Policy, Investment, and Global Deployment Trends in Nuclear Energy
#
# **2. Search Queries:**
#
# **Latest Developments and News:**
# - "Recent breakthroughs in advanced nuclear reactors 2023"
# - "New nuclear power plant projects launched globally 2023"
# - "Innovative nuclear technologies announced this year"
#
# **Key Statistics or Data:**
# - "Global nuclear energy capacity growth 2020-2023"
# - "Statistics on deployment of small modular reactors"
# - "Nuclear waste management advancements data 2023"
#
# **Expert Analysis or Studies:**
# - "Expert reviews on next-generation nuclear reactors"
# - "Academic studies on nuclear fuel innovations"
# - "Conference reports on nuclear energy future outlook"
#
# **Future Outlook:**
# - "Future prospects for nuclear energy development"
# - "Predictions for nuclear energy policy and investment 2025 and beyond"
# - "Potential impact of new nuclear technologies on global energy mix"
#
# This focused plan will help gather comprehensive, up-to-date insights on cutting-edge developments in nuclear energy efficiently.
# ---------- ToolCallRequestEvent (research_agent) ----------
# [FunctionCall(id='call_p34V0jZ6l5iQMG1sHE8ncdeS', arguments='{"query": "Recent breakthroughs in advanced nuclear reactors 2023"}', name='web_search_tool'), FunctionCall(id='call_AlfTTKzzpqCOMAhI2i5VV6DV', arguments='{"query": "New nuclear power plant projects launched globally 2023"}', name='web_search_tool'), FunctionCall(id='call_NDEwqvZhJEI1f3BWV5az4C0Z', arguments='{"query": "Innovative nuclear technologies announced this year"}', name='web_search_tool'), FunctionCall(id='call_6LZYOfYLodW7xs0Q4yNmCWRw', arguments='{"query": "Global nuclear energy capacity growth 2020-2023"}', name='web_search_tool'), FunctionCall(id='call_ayuI9a4YXJBXqXhDQRrs05Fd', arguments='{"query": "Statistics on deployment of small modular reactors"}', name='web_search_tool'), FunctionCall(id='call_4UPhQxIuVlVgLfvxRlBvAKc5', arguments='{"query": "Nuclear waste management advancements data 2023"}', name='web_search_tool'), FunctionCall(id='call_uNEzZglx6IQsKGv8TpdnvoS6', arguments='{"query": "Expert reviews on next-generation nuclear reactors"}', name='web_search_tool'), FunctionCall(id='call_iPLzAleiuVItuqYGRoBfyNNg', arguments='{"query": "Academic studies on nuclear fuel innovations"}', name='web_search_tool'), FunctionCall(id='call_QspuyEyp0FiblOpJOxs158Cy', arguments='{"query": "Conference reports on nuclear energy future outlook"}', name='web_search_tool')]
# ---------- ToolCallExecutionEvent (research_agent) ----------
# [FunctionExecutionResult(content='[{\'title\': \'Laying the Foundation for New and Advanced Nuclear Reactors in ...\', \'url\': \'https://www.nationalacademies.org/publications/26630\', \'markdonw\': \'Consensus/Advisory ActivityConsensus/Advisory ActivityAn activity carried out by an appropriately knowledgeable and balanced ad hoc committee, the purpose of which is to provide formal advice on the matters posed in the statement of task for the activity. These activities follow institutional policies and procedures to adhere to Section 15 of the Federal Advisory Committee Act (FACA).# Laying the Foundation for New and Advanced Nuclear Reactors in the United States### Dropdown items- Copy link- - - - CompletedTopics    Nuclear reactors can provide low-carbon energy, and advanced nuclear technologies could play an important role in moving the United States towards a zero-carbon future. Next-generation nuclear reactors have the potential to be smaller, safer, less expensive to build, and better integrated with the modern grid. However, the technical, economic, and regulatory outlook for these technologies remains uncertain. This study will assess the future of new and advanced nuclear reactor technologies and identify the opportunities and barriers to commercialization.This study operates in parallel with a  on the fuel cycle and waste aspects of these advanced reactor designs.   ## Featured publication### Pathways for New Nuclear Development: Proceedings of a WorkshopProceedings·2025Recent years have brought a renewed focus on the potential for nuclear energy to help meet the United States\\\' growing demands for abundant, reliable, low-carbon energy. Trends such as the increased electrification of transportation and industrial processes, along with the rapid expansion of data cen...View details![]( DescriptionThe National Academies of Sciences, Engineering, and Medicine will appoint an ad hoc committee of experts to identify opportunities and barriers to the commercialization of new and advanced nuclear reactor technologies in the United States over the next 30 years as part of a decarbonization strategy. Specific topics the committee will examine include:- The research, development, and demonstration needed for new and advanced nuclear reactor technologies to reach commercial readiness, the potential for leveraging technological developments outside the nuclear energy sector, and the manufacturing, construction, financial, societal, and other barriers associated with their deployment;- The operational characteristics of these technologies, including their implications for safety, security, and non-proliferation, as well as their interaction with other low-carbon generation and storage resources that may be relevant to a changing electricity system;- The economic, regulatory, and business challenges associated with commercialization of these technologies;- The implications of these technologies for the front- and back-end of the fuel cycle;- The viability of these technologies in applications outside the electricity sector, for example in desalination, water and wastewater treatment, hydrogen production, or process heat;- The role of the U.S. Government in sponsoring the development and commercialization of new and advanced nuclear reactor technologies to provide clean energy, to address national-security and nonproliferation goals, or to assist in nuclear exports; and- The future workforce and educational needs to support the research, development, and deployment of these technologies.## Contributors## CommitteeRichard A. MeserveChairAhmed AbdullaMemberTodd AllenMemberJaquelin CochranMemberMichael L. CorradiniMemberRichard CupittMemberLeslie DewanMemberMichael FordMemberKirsty GoganMemberNing KangMemberAllison M. MacfarlaneMemberDavid K. OwensMemberJames RispoliMemberSola TalabiMemberSteven J. ZinkleMemberConflict of Interest DisclosureThe conflict of interest policy of the National Academies of Sciences, Engineering, and Medic ...
# ---------- ToolCallSummaryMessage (research_agent) ----------
# [{'title': 'Laying the Foundation for New and Advanced Nuclear Reactors in ...', 'url': 'https://www.nationalacademies.org/publications/26630', 'markdonw': 'Consensus/Advisory ActivityConsensus/Advisory ActivityAn activity carried out by an appropriately knowledgeable and balanced ad hoc committee, the purpose of which is to provide formal advice on the matters posed in the statement of task for the activity. These activities follow institutional policies and procedures to adhere to Section 15 of the Federal Advisory Committee Act (FACA).# Laying the Foundation for New and Advanced Nuclear Reactors in the United States### Dropdown items- Copy link- - - - CompletedTopics    Nuclear reactors can provide low-carbon energy, and advanced nuclear technologies could play an important role in moving the United States towards a zero-carbon future. Next-generation nuclear reactors have the potential to be smaller, safer, less expensive to build, and better integrated with the modern grid. However, the technical, economic, and regulatory outlook for these technologies remains uncertain. This study will assess the future of new and advanced nuclear reactor technologies and identify the opportunities and barriers to commercialization.This study operates in parallel with a  on the fuel cycle and waste aspects of these advanced reactor designs.   ## Featured publication### Pathways for New Nuclear Development: Proceedings of a WorkshopProceedings·2025Recent years have brought a renewed focus on the potential for nuclear energy to help meet the United States\' growing demands for abundant, reliable, low-carbon energy. Trends such as the increased electrification of transportation and industrial processes, along with the rapid expansion of data cen...View details![]( DescriptionThe National Academies of Sciences, Engineering, and Medicine will appoint an ad hoc committee of experts to identify opportunities and barriers to the commercialization of new and advanced nuclear reactor technologies in the United States over the next 30 years as part of a decarbonization strategy. Specific topics the committee will examine include:- The research, development, and demonstration needed for new and advanced nuclear reactor technologies to reach commercial readiness, the potential for leveraging technological developments outside the nuclear energy sector, and the manufacturing, construction, financial, societal, and other barriers associated with their deployment;- The operational characteristics of these technologies, including their implications for safety, security, and non-proliferation, as well as their interaction with other low-carbon generation and storage resources that may be relevant to a changing electricity system;- The economic, regulatory, and business challenges associated with commercialization of these technologies;- The implications of these technologies for the front- and back-end of the fuel cycle;- The viability of these technologies in applications outside the electricity sector, for example in desalination, water and wastewater treatment, hydrogen production, or process heat;- The role of the U.S. Government in sponsoring the development and commercialization of new and advanced nuclear reactor technologies to provide clean energy, to address national-security and nonproliferation goals, or to assist in nuclear exports; and- The future workforce and educational needs to support the research, development, and deployment of these technologies.## Contributors## CommitteeRichard A. MeserveChairAhmed AbdullaMemberTodd AllenMemberJaquelin CochranMemberMichael L. CorradiniMemberRichard CupittMemberLeslie DewanMemberMichael FordMemberKirsty GoganMemberNing KangMemberAllison M. MacfarlaneMemberDavid K. OwensMemberJames RispoliMemberSola TalabiMemberSteven J. ZinkleMemberConflict of Interest DisclosureThe conflict of interest policy of the National Academies of Sciences, Engineering, and Medicine ( prohibits the appointment of an individua ...
# [{'title': 'Nuclear Power', 'url': 'https://www.iea.org/energy-system/electricity/nuclear-power', 'markdonw': "Close SearchSearchYou are connecting via IP recognition from.If you wish to proceed, click on Connect.If you prefer to log into your personal account, please sign in below.OREmail *ErrorPassword * EyeErrorSign inSign in##### Create an accountCreate a free IEA account to download our reports or subcribe to a paid service.cross#### A new era for nuclear energy beckons as projects, policies and investments increaseAs the world’s second-largest source of low-emissions electricity after hydropower, nuclear power today produces just under 10% of global electricity supply. Now, fresh momentum around the world has the potential to open a new era for nuclear energy.Power generation from the global fleet of nearly 420 active nuclear reactors is set to reach a record high in 2025 as Japan restarts production, maintenance works are completed in France, and new reactors begin commercial operations in various markets, including China, Europe, India and Korea. Meanwhile, more than 60 nuclear reactors are currently under construction – representing over 70 gigawatts (GW) of capacity – and governments’ interest in nuclear power is at its highest level since the oil crisis in the 1970s, reflecting efforts to bolster energy security, accelerate clean energy transitions and meet rising demand for electricity. Over 40 countries now have plans to expand its use.GWCreated with Highcharts 9.3.3201020122014201620182020202220242026202820302032203420362038204020422044204620482050020040060080010001200#### Notes and sources     Chevron down 16Other EMDE = Emerging market and developing economies excluding China.IEA analysis based on IEA (2024), ### Country and regional highlights     Chevron downMany countries have recently taken steps to extend operations at existing nuclear power plants and build new ones.Many countries have recently taken steps to extend operations at existing nuclear power plants and build new ones.Countries and regions making notable progress to advance nuclear electricity include:- **Belgium** recently decided to extend the operation of two existing reactors from 2025 to 2035, which will meet around 15% of electricity demand.- **Canada** introduced an investment tax credit of up to 30% for clean energy technologies in late 2022, explicitly including small modular reactors (SMRs), and Canada’s Infrastructure Bank granted a loan to build an SMR as early as 2028 at an existing nuclear site.- **China** continues to lead in nuclear capacity additions, with two large reactors completed in 2022, four more starting construction and plans to further accelerate deployment.- **Finland** completed Olkiluoto 3 in 2023, the first new nuclear reactor in Western Europe in 15 years.- **France** agreed in 2022 to construct 6 new large nuclear reactors that will meet around 10% of electricity demand, with an option to build 8 more. The first reactor is targeting 2035 for commissioning.- **Japan** established a law in 2023 under the Green Transformationinitiative that allows power companies to operate nuclear assets for longer, in some cases over 60 years, by excluding periods during which they were suspended for safety reasons. A new policy announced in December 2022 also aims to maximise the use of the existing fleet and foresees the development of new nuclear power plants.- **Korea** aims for nuclear power to expand to over 30% of electricity generation by 2030 under the 10th Basic Energy Plan, up from 28% currently **.**- In **Poland,** the cabinet formally approved in November 2022 the decision that the first nuclear power plant in Poland will use three Westinghouse AP1000 units. In addition, the development of APR1400 units are progressing, and SMRs continue to gain traction among the private sector.- **The United Kingdom**'s 2022 Energy Security Strategy targets 8 new large reactors, as well as SMRs, to achieve nuclear power capacity of ...
# [{'title': '2023 Scientific Forum: Nuclear Innovations for Net Zero', 'url': 'http://www.iaea.org/newscenter/news/2023-scientific-forum-nuclear-innovations-for-net-zero', 'markdonw': '- - - - - - - - - Share# 2023 Scientific Forum: Nuclear Innovations for Net ZeroLeaders from around the world meeting at the IAEA Scientific Forum: Nuclear Innovations for Net Zero agreed: the effects of climate change are undeniable, and nuclear energy is part of the solution to mitigate the climate crisis and reducing carbon emissions.28 September 2023**Joanne Liou**, IAEA Office of Public Information and CommunicationScientific Forum 2023: Nuclear Innovations For Net Zero - YouTubeTap to unmuteIAEAvideoLearn more about nuclear science and technology.Videos from the IAEA are currently available for use under the standard YouTube license. For further rights please contact us.High-resolution downloads and b-roll footage are available for all IAEA-generated content upon request. www.iaea.org/contact/multimedia-unitIAEA featured videos61 videos IAEAvideo44K subscribers0:00Time elapsed /1:31Time duration 1 minute, 31 secondsLeaders from around the world meeting at the  agreed: the effects of climate change are undeniable, and nuclear energy is part of the solution to mitigate the climate crisis and reducing carbon emissions.Innovations will support the integration of nuclear energy into the solutions needed to meet net zero goals and is already playing an essential role in further enhancing the performance, safety and life of existing reactor fleets, IAEA Director General Rafael Mariano Grossi said at the opening of the Forum on Tuesday on the margins of the IAEA’s\u202f.However, Mr Grossi noted that achieving a fair and enabling investment environment for new nuclear projects remains an uphill battle. “We are not at a level playing field, yet, when it comes to financing nuclear projects,” he said.Over two days, experts discussed new nuclear power technologies and how innovations such as artificial intelligence, robotics and 3D printing can advance nuclear power, and how reactors can be used for applications beyond electricity by providing heat for industrial processes or freshwater through nuclear desalination (see the ).Watch the , and read the latest\xa0## The role of nuclear power and innovations for a net zero world!The President of Ghana, Nana Akufo-Addo, shared Ghana\'s plans to include nuclear energy in the country’s electricity generation mix. (Photo: D. Calma/IAEA)There is growing global interest in nuclear energy, and countries are acting on this interest. In the opening session of the Scientific Forum, the President of Ghana, Nana Akufo-Addo, shared his plans for the inclusion of nuclear energy in the country’s electricity generation mix. “We’re committed to a clean, equitable energy transition that harnesses the full potential of all low carbon sources, including nuclear power,” President Akufo-Addo said. “Nuclear power will play a significant part in this transformation.”Ghana is analysing small modular reactors (SMRs) and their potential for rapid deployment for clean and affordable energy. “We are working with industry experts to study the feasibility of deploying this new technology in Ghana,” President Akufo-Addo said.In the United States of America, where nuclear power provides the single largest source of clean energy, “reaching our 2050 net zero goals depends on at least tripling our nuclear energy capacity to 300 gigawatts or more,” said US Secretary of Energy Jennifer Granholm. The US Government has invested “billions of dollars in the future of nuclear energy, creating historic tax incentives for investments in new facilities and production of nuclear energy,” and the development of a domestic fuel supply chain is underway, she addedThe US Department of Energy recently released , a set of reports to accelerate the deployment of clean energy technologies, including advanced nuclear reactors. Advanced reactors are key to reachi ...
# [{'title': 'Nuclear Power in the World Today', 'url': 'https://world-nuclear.org/information-library/current-and-future-generation/nuclear-power-in-the-world-today', 'markdonw': ' /  /  / Nuclear Power in the World Todaycurrent and future generation# Nuclear Power in the World TodayUpdated Tuesday, 21 April 2026- **The first commercial nuclear power stations started operation in the 1950s.**- **Nuclear energy now provides about 9% of the world\'s electricity from about 440 power reactors.**- **31 countries generate electricity from nuclear energy.**- **Nuclear provides over 20% of the world’s low-carbon electricity.**- **Nuclear is the world\'s second largest source of low-carbon power.**- **Over 50 countries utilize nuclear energy in about 220 research reactors. In addition to research, these reactors are used for\xa0the production of medical and industrial isotopes, as well as for training.**Nuclear technology uses the energy released by splitting the atoms of certain elements. It was first developed in the 1940s, and during the Second World War research initially focused on producing bombs.\xa0In the 1950s attention turned to the peaceful use of nuclear fission, controlling it for power generation.\xa0For more information, see page on\xa0.Civil nuclear power can now boast around 20,000 reactor years of operating experience, and nuclear power plants are operational in 31 countries worldwide. In fact, through regional transmission grids, many more countries depend in part on nuclear-generated power, particularly in Europe.When the commercial nuclear industry began in the 1960s, there were clear boundaries between the industries of the East and West. Today,\xa0the nuclear industry is characterized by international commerce. A reactor under construction in Asia today may have components supplied from South Korea, Canada, Japan, France, Germany, Russia, and other countries. Similarly, uranium from Australia or Namibia may end up in a reactor in the UAE, having been converted in France, enriched in the Netherlands, deconverted in the UK and fabricated in South Korea.The uses of nuclear technology extend well beyond the provision of low-carbon energy. It helps control the spread of disease, assists doctors in their diagnosis and treatment of patients, and powers our most ambitious missions to explore space. These varied uses position nuclear technologies at the heart of the world\'s efforts to achieve sustainable development. For more information, see page on .## Key statisticsIn 2024\xa0nuclear plants supplied 2667 TWh of electricity, up from 2601 TWh in 2023.![]( 1: Nuclear electricity production 1970-2024\xa0(source: World Nuclear Association, IAEA PRIS)_![]( 2: World electricity production by source 2023\xa0(source: International Energy Agency)_Fourteen countries in 2024\xa0produced at least one-quarter of their electricity from nuclear. France gets up to around 70% of its electricity from nuclear energy, while Ukraine, Slovakia and Hungary get about half from nuclear. Japan was used to relying on nuclear power for more than one-quarter of its electricity and is expected to return to somewhere near that level.![]( 3: Nuclear generation by country 2024\xa0(source: World Nuclear Association, IAEA PRIS)_## Developments in 2026**Grid connections**| Reactor name | Grid connection | Net capacity (MWe) | Location || --- | --- | --- | --- ||  | 2026-02-13 | 1116 | China ||  | 2026-03-12 | 1117 | China |**Construction starts**| Reactor name | Construction start | Net capacity (MWe) | Location || --- | --- | --- | --- ||  | 2026-01-16 | 1,116 | China ||  | 2026-01-31 | 1,200 | Russia ||  | 2026-02-05 | 1,100 | Hungary ||  | 2026-03-01 | 630 | India ||  | 2026-03-01 | 630 | India ||  | 2026-05-10 | 1,116 | China ||  | 2026-05-29 | 1,340 | South Korea ||  | 2026-06-04 | 55 | Uzbekistan |**Permanent shutdowns**N/A## World overviewAll parts of the world are involved in nuclear power development. For detailed country-level information, see t ...
# [{'title': 'Small modular reactors (SMR) | IAEA', 'url': 'http://www.iaea.org/topics/small-modular-reactors', 'markdonw': '- - - - - - - - - ![]( Small modular reactors- Small and medium-sized or modular reactors are an option to fulfil the need for flexible power generation for a wider range of users and applications. Small modular reactors, deployable either as single or multi-module plant, offer the possibility to combine nuclear with alternative energy sources, including renewables.## Small modular reactors: flexible and affordable power generationGlobal interest in small and medium sized or modular reactors has been increasing due to their ability to meet the need for flexible power generation for a wider range of users and applications and replace ageing fossil fuel-fired power plants. They also display an enhanced safety performance through inherent and passive safety features, offer better upfront capital cost affordability and are suitable for cogeneration and non-electric applications. In addition, they offer options for remote regions with less developed infrastructures and the possibility for synergetic hybrid energy systems that combine nuclear and alternate energy sources, including renewables.Many Member States are focusing on the development of small modular reactors, which are defined as advanced reactors that produce electricity of up to 300 MW(e) per module. These reactors have advanced engineered features, are deployable either as a single or multi-module plant, and are designed to be built in factories and shipped to utilities for installation as demand arises.There are more than 80 SMR designs and concepts globally. Most of them are in various developmental stages and some are claimed as being near-term deployable. There are currently four SMRs in advanced stages of construction in Argentina, China and Russia, and several existing and newcomer nuclear energy countries are conducting SMR research and development.The IAEA is coordinating the efforts of its Member States to develop SMRs of various types by taking a systematic approach to the identification and development of key enabling technologies, with the goal to achieve competitiveness and reliable performance of such reactors. The Agency also helps them address common infrastructure issues that could facilitate the SMRs’ deployment.## Related resources- - - ## Related News]( STORY### 5 June 2026]( STORY### 20 May 2026]( STORY### 15 May 2026]( STORY### 9 December 2025## Upcoming Events16 – 18 Jun 2026### ## Publications]( December 2025### ]( October 2025### ]( May 2025### ]( October 2024### #### More on the IAEA1. 2. 3. #### Scientific resources1. 2. 3. 4. #### Resources1. 2. 3. #### Documents1. 2. 3. 4. #### Stay in Touch          '}, {'title': 'What is holding up progress on small modular reactors? - GIS Reports', 'url': 'https://www.gisreportsonline.com/r/smrs/', 'markdonw': 'Factory-built reactors offer a scalable, low-carbon solution for climate and digital needs yet still face legacy challenges to nuclear deployment.!July 2023: The factory-assembled core of a small modular reactor is transferred by crane to a ship in China for delivery to the customer rather than being assembled on site, as is done with conventional nuclear reactors. © Getty Images## In a nutshell- Governments and industry reconsider SMRs as electricity demand soars- Tech giants pursue SMRs to secure clean power for the digital era- Regulatory, financial and fuel constraints hinder SMR commercialization- For comprehensive insights, tune into our AI-powered podcast Interest in nuclear energy is undergoing a noticeable resurgence, with small modular reactors (SMRs) attracting heightened attention worldwide from governments, utilities and technology firms alike. These modern nuclear generators are compact, factory-built and scalable – making them another important source of clean power to assist in decarbonizing energy systems while meeting rapidly growing electricity demand.Enthusi ...
# [{'title': 'Geological repositories, emerging technologies, and global pathways', 'url': 'https://www.sciencedirect.com/science/article/pii/S2772416626000410', 'markdonw': ' - View\xa0**PDF**- Download full issueSearch ScienceDirect]( "Go to Journal of Hazardous Materials Advances on ScienceDirect")## , February 2026, 101042]( Next-generation nuclear waste management: Geological repositories, emerging technologies, and global pathwaysAuthor links open overlay panelKulmaniMehara, Devulapalli PraveenKumarb, Shakti PrakashJenac, KeertiRaid, MahitJaine, SandeepG Mf, VasanthaseelanSg, Ritesh PrathapSinghhShow moreAdd to MendeleyCite Under a Creative Commons Open access## Highlights- •Global nuclear waste exceeds 370,000 tons, projected to 400,000 tons by 2035.- •Geological repositories analyzed: Onkalo (5500 t) and WIPP (175,000 m³).- •Emerging solutions: borehole disposal, transmutation, vitrification, Synroc.- •Risk models show <1 % failure probability with IAEA and EPA compliance.- •Future innovations: graphene barriers, robotics, and AI-enabled monitoring.- •Integrated strategies support safe, adaptive, and net-zero aligned disposal.## AbstractThe safe management of nuclear waste remains a central challenge for sustaining nuclear energy in the low-carbon transition, with a global inventory exceeding 370,000 metric tons and increasing by 10,000 tons annually. This review synthesizes advances in waste classification, repository design, emerging disposal technologies, environmental safeguards, and future directions. Nuclear waste is categorized into low-level (90% volume, <1% radioactivity), intermediate-level (7% volume, 4% radioactivity), and high-level wastes (2% volume, >95% radioactivity), alongside highly radioactive spent fuel (10¹⁰–10¹⁴ Bq/g). Current strategies emphasize geological repositories such as Onkalo (5500 tons, 400–500 m depth) and WIPP (175,000 m³, 655 m depth), which employ multi-barrier systems but face challenges including high heat output (10–20 kW/ton) and material durability (10⁻⁵/year corrosion). Complementary approaches deep borehole disposal (3–5 km depth, 1–2 billion USD), partitioning and transmutation (>90% toxicity reduction), and immobilization via vitrification (leach rate ∼10⁻⁶ g/m²/day) are advancing the safety and sustainability of disposal. Risk assessments, supported by IAEA safety standards, demonstrate <1% failure probability over 10,000 years, while future innovations in advanced materials (e.g., graphene by 2030), robotics (RADBOT deployment by 2028), and AI-driven monitoring (20% predictive improvement by 2035) could reduce long-term risks by 30% by 2040. The findings underscore the critical role of geological repositories, enhanced by emerging technologies, and highlight the need for interdisciplinary collaboration to ensure secure, sustainable nuclear waste disposal aligned with global net-zero goals by 2050. By strengthening the scientific basis for next-generation disposal technologies, this study contributes on responsible management of hazardous materials## Graphical abstract!1. ")2. - Previousarticle in issue- Nextarticle in issue## KeywordsWasteGeological repositoriesSpent fuelEnvironmental impactSafety considerationsResponsible managementSustainable practicesRecommended articles## Data availabilityNo data was used for the research described in the article.© 2026 The Authors. Published by Elsevier B.V.'}, {'title': 'Low-Level Waste Disposal Statistics | Nuclear Regulatory Commission', 'url': 'https://www.nrc.gov/waste/llw-disposal/licensing/statistics', 'markdonw': '!**Official websites use .gov**A **.gov** website belongs to an official government organization in the United States.!**Secure .gov websites use HTTPS**A **lock** ( LockLocked padlock) or ** means you’ve safely connected to the .gov website. Share sensitive information only on official, secure websites.Section Navigation#### NavigationSpotlight#### Choose a section# Low-Level Waste Disposal StatisticsApproximately 3 ...
# [{'title': 'Argonne plays "bad guy" to test next-gen nuclear reactor concepts', 'url': 'https://www.anl.gov/article/argonne-plays-bad-guy-to-test-nextgen-nuclear-reactor-concepts', 'markdonw': 'ByKristen Mally Dean|January 27, 2026Argonne uses its world-class facilities, expertise and ingenuity to combat insider threats to nuclear power plants.!Good guy Darius Lisowski, Argonne’s group manager of reactor safety testing and analysis, takes time to play "bad guy" in order to thwart those who would interfere with safe nuclear reactor operations. (Image by Argonne National Laboratory.)Throughout its decades-long history, nuclear energy has undergone alternating stages of intense growth, skepticism and uncertain status. Now — and just in time to reliably power an AI-driven economy — it’s undergoing a next-gen glow-up.Experts at the U.S. Department of Energy’s (DOE) Argonne National Laboratory are more than in lockstep with the latest  makeover; they’re several steps ahead. That’s no surprise. The lab came into existence 80 years ago in response to the Manhattan Project, and it is responsible for ground-breaking discoveries that have informed the design of every nuclear reactor operating anywhere in the world.Today, Argonne is partnering with its DOE sister laboratories to look more closely at passive safety systems, which will be used prevalently in the next generation of nuclear power plants. Passive safety systems rely on natural processes, such as gravity and circulation, to cool or safely shut down reactors without active power sources or human intervention.\xa0The underlying physics of these systems will make next-gen nuclear reactors safer. However, their novel technologies may also present a soft underside to insider threats and saboteurs.> “We want to know what would cause these systems to not work. In this project, we’re focusing on bad guys who might have authorized access and knowledge of inside workings. What could they do to make things break?” — Darius Lisowski, Argonne National LaboratoryBefore next-gen reactors are constructed and put into use, the security of passive safety systems are undergoing careful review. Using Argonne’s world-class facilities, and a willingness to think outside the box, experts are getting nuclear energy ready for its next close-up.#### Security-informed designBy depending on passive safety, nuclear power plants reduce the risk of mechanical or electrical failures during emergencies. Passive safety principles are already in use at many reactors currently operating in the U.S. and around the world. There is ample data collected over decades that show how effective they are.The reactors of tomorrow build on this existing data and incorporate new technology. This means new designs must be tested and approved before they are licensed for construction. The nuclear industry is, by necessity, a standard-bearer for safety and quality. Nothing gets approved for construction and commissioning that can’t prove it is safe and secure.“Natural phenomena threats are unique to new reactors,” said Darius Lisowski, group manager of reactor safety testing and analysis and principal investigator at Argonne’s Natural Convection Shutdown Heat Removal Test Facility (NSTF). \u200b“We want to know what would cause these systems to not work. In this project, we’re focusing on bad guys who might have authorized access and knowledge of inside workings. What could they do to make things break?”According to Lisowski, research began more than two years ago and included input from Argonne and DOE’s Sandia National Laboratories, Oak Ridge National Laboratory and Idaho National Laboratory. A roundtable brainstormed bad acts that a saboteur might try. What if someone left open an access hatch that should be closed? Or deliberately plugged a pathway to prevent cooling fluid from going where it needed to go?List in hand, they then looked closely at how likely and how impactful such acts would be. They detailed their findings i ...
# [{'title': 'Fuel Cycle Research | PNNL', 'url': 'https://www.pnnl.gov/fuel-cycle-research', 'markdonw': "# Fuel Cycle   Research### Innovative nuclear fuel   concepts and methodsOpenStarting in Spain, a test cask containing simulated spent nuclear fuel (SNF) rods and assemblies gathered data , including transport by truck, ship, and rail, and transfer by crane from each mode to the next until reaching Colorado. The white box behind the cask housed two data acquisition boxes, 20 batteries, and scores of cables connected to sensors that . The data can be used to inform Nuclear Regulatory Commission regulations on the transport of SNF and to help industry better understand the performance of storage and transportation casks.Honored with a DOE Secretary of Energy's Achievement Award in 2018, the international team include PNNL, Sandia National Laboratories, Equipos Nucleares, S.A. (ENSA) and ENRESA (Empresa Nacional de Residuos Radiactivos, S.A.) of Spain, Transportation Technology Center, Inc., Korea Radioactive Waste Agency, Korea Atomic Energy Research Institute, and KEPCO Nuclear Fuel.PNNL draws on a decade of innovation and experience in the nuclear fuel cycle. Scientists and engineers develop and evaluate new, safer, and economically improved fuels; improve methods for fuel fabrication; and evaluate alternative means of recycling, storing, and transporting spent nuclear fuel.Much of this work is sponsored by the Department of Energy (DOE) Office of Nuclear Energy (NE) and the Nuclear Regulatory Commission (NRC), in partnership with the nuclear industry and other national laboratories.Post-irradiation examination of spent nuclear fuels - YouTubeTap to unmute Pacific Northwest National Laboratory18K subscribersPNNL materials researchers are studying the behavior of spent nuclear fuel rods to better understand how they will fare in extended storage conditions and during transportation.## Advanced nuclear fuelPNNL capabilities include online process monitoring,  to better understand fuel performance and to speed the development and qualification of improved fuels.For example, PNNL is among the DOE national laboratories working with industry to model, simulate, and evaluate accident-tolerant fuels (ATF). On behalf of the NRC, PNNL also reviews advanced fuel concepts submitted by industry vendors.It is important to understand how advanced alloys and materials will perform under the harsh operating environments of advanced reactors. PNNL draws upon hot cell facilities and advanced microscopy techniques to integrate atomic-resolution chemical imaging, materials processing, surface modification, mechanical testing, and multiscale modeling to characterize and measure the performance of advanced materials.Uranium is a key ingredient in nuclear fuel, but land-based mining comes with environmental issues. In 2018, for the first time, researchers at PNNL and LCW Supercritical Technologies in Moscow. Idaho, devised  to make yellowcake, a powdered form of uranium. This approach could eventually provide commercially attractive nuclear fuel from the oceans, the largest source of uranium on earth.## Fuel fabricationPNNL develops and tests new fabrication and extrusion methods to make fuel for advanced reactors. For instance, researchers developed oxide dispersion cladding using advanced extrusion techniques for uranium-molybdenum and uranium-zirconium alloys. PNNL’s hot cells, mechanical test frames, and  assets provide testing and nano-level evaluation of new fuels, cladding, and associated materials.### File## Spent fuel dispositionSpent nuclear fuel (SNF) still retains significant residual energy and must either be recycled to recover fissile material for additional use or stored securely for eventual disposal. PNNL has a history of innovation in immobilizing, transporting, storing, or reprocessing SNF. For example, nuclear experts are establishing technologies and testing processes to support proliferation-resistant management of spent fue ...
# [{'title': 'World Nuclear Outlook Report', 'url': 'https://world-nuclear.org/our-association/publications/global-trends-reports/world-nuclear-outlook-report', 'markdonw': " /  /  /  / World Nuclear Outlook Report# World Nuclear Outlook ReportUpdated Thursday, 22 January 2026The World Nuclear Outlook Report\xa0reviews national targets for nuclear capacity and assesses these against the global goal to triple nuclear capacity by 2050. It also reviews the current and future contribution of nuclear technology to energy provision and summarises the range of different nuclear reactor technologies available.Download the report as a pdf]( Full reportWorld Nuclear Outlook ReportExecutive Summary - World Nuclear Outlook ReportGlobal nuclear capacity would expand to 1446 GWe by 2050 if the continued operation of existing reactors and the deployment of new nuclear build meet targets set by governments for national nuclear capacity.World Nuclear Outlook ReportChapter 1: Review of nuclear energyThis chapter sets the global context for nuclear energy, examining how nuclear generation has evolved, what technologies dominate today, and why nuclear power is increasingly viewed as essential for decarbonization, rising electricity demand, reliability, and energy security through mid-century.World Nuclear Outlook ReportChapter 2: Nuclear power technology developmentThis chapter explains how emerging reactor designs broaden nuclear’s role beyond large water-cooled plants, categorizing technologies by size and coolant and linking them to new applications. It shows how advanced reactors could support electricity, heat, industry, hydrogen, desalination, storage, and mobile uses.World Nuclear Outlook ReportChapter 3: Global energy developmentsThis section of Chapter 3 documents the growing\xa0governmental, financial, and corporate endorsement of nuclear energy globally.Assessments of national plans for nuclear energy are detailed individually, below.World Nuclear Outlook ReportChapter 4: Assessment of overall global nuclear capacityThis chapter evaluates whether national nuclear ambitions to 2050 are achievable, examining the combined roles of existing reactor lifetimes, new build pipelines, construction rates, and policy support to assess if global nuclear capacity can realistically meet climate and energy security objectives.### Countries with reactors in operationWorld Nuclear Outlook ReportArgentina - World Nuclear Outlook ReportArgentina operates three reactors, is extending lifetimes, and is expanding nuclear capacity. Alongside the 29 MWe CAREM SMR under construction, plans include either a new large reactor or multiple domestically developed SMRs at Atucha.World Nuclear Outlook ReportArmenia - World Nuclear Outlook ReportArmenia relies on a single nuclear reactor for over a quarter of its electricity, is extending its operating life to 2036, and is pursuing new capacity through either a large replacement plant or small modular reactors with international partners.World Nuclear Outlook ReportBelarus - World Nuclear Outlook ReportBelarus now meets around 40% of its electricity demand from the two-unit Ostrovets nuclear plant. The government is assessing options for further expansion, including a second nuclear plant or an additional unit at Ostrovets.World Nuclear Outlook ReportBelgium - World Nuclear Outlook ReportBelgium has modified its nuclear phase-out, extending key reactors beyond 2035 and potentially to 2045 while older units close. The government now plans lifetime extensions and new build, aiming to maintain and eventually double nuclear capacity as part of its energy security strategy.World Nuclear Outlook ReportBrazil - World Nuclear Outlook ReportBrazil plans significant nuclear expansion by 2050. National strategy prioritizes large reactors initially, with SMRs and advanced technologies later, alongside development of domestic SMR and microreactor capabilities.World Nuclear Outlook ReportBulgaria - World Nuclear Outlook ReportBulgari ...
# ---------- TextMessage (research_analyst) ----------
# # Comprehensive Overview of New Developments in Nuclear Energy (2023–2026)
#
# ## Executive Summary
# - **Technological Innovation & Diversification**: The nuclear sector is experiencing a renaissance, with advanced reactors—including Small Modular Reactors (SMRs), fast reactors, molten salt reactors (MSRs), and high-temperature gas-cooled reactors—moving from prototypes to commercial readiness. Notably, the first operational SMRs (e.g., China's HTR-PM and Russia’s Akademik Lomonosov) have demonstrated viability.
# - **Global Capacity & Deployment**: Approximately 440 reactors operate in 31 countries, generating nearly 10% of the world's electricity. Of these, over 70 GW are under construction globally, with China leading expansion efforts and increased commitments from the U.S., Europe, and emerging economies.
# - **Policy & Investment Surge**: The momentum is driven by policies supporting decarbonization, significant government investments—including climate and energy security initiatives—and rising private sector investment, with multibillion-dollar commitments from major banks and tech firms.
# - **Emerging Technologies & Industry Trends**: Innovations such as passive safety systems, AI for safety and operational monitoring, advanced fuels (e.g., TRISO, HALEU), and modular construction are key drivers. The global focus is on safety, cost reduction, supply chain diversification, and licensing reforms.
# - **Challenges & Opportunities**: Key hurdles include high capital costs, lengthy licensing processes, fuel supply limitations (notably HALEU), waste management complexities, and public acceptance. Nonetheless, international collaboration, policy reforms, and technological advances offer pathways to overcome these barriers.
# - **Future Outlook**: A projected global nuclear capacity of 514–950 GW by 2050 under various scenarios, with SMRs expanding significantly, accounting for up to 30-50% of new capacity in a rapid deployment scenario by mid-century.
#
# ## Background & Current State
# - **Global Landscape**: As of 2025, 416 reactors operate, producing 2667 TWh annually (~9% of global electricity). Major countries include the USA, France, China, Russia, and South Korea.
# - **Recent Developments**:
#   - *Construction & Operational Milestones*: Multiple reactors are under construction across Asia, Europe, and Africa, including China’s new large reactors and SMRs, Russia’s floating plants, and early projects in Africa (Ghana, Rwanda).
#   - *Reactor Life Extensions*: Over 60 reactors have received extensions, rejuvenating the existing fleet amid aging reactors.
#   - *Policy & Investment Trends*: The US’s Inflation Reduction Act and international commitments aim to triple capacity by 2050. China and Russia are expanding aggressively, with China set to overtake France in total capacity.
#   - *Technology Deployment*: The world’s first commercial SMR—the Chinese HTR-PM—began operation in 2023, while several projects are under review for licensing in the US, Canada, and UK.
#
# ## Analysis & Insights
# - **Main Trends**:
#   - *Technological Diversification*: Strong growth in SMRs, fast reactors, MSRs, and gas-cooled reactors broadens application scope.
#   - *Industrial & Non-electric Uses*: Power and heat co-generation, hydrogen production, and industrial applications are becoming central.
#   - *Private & Public Investment*: The private sector’s involvement (e.g., Amazon, Google, tech firms) and government incentives (tax credits, loan guarantees) are catalyzing deployment.
#   - *Supply Chain & Regulatory Reforms*: Efforts to streamline licensing, expand fuel supply (notably HALEU), and reinforce safety standards are seen as critical.
# - **Perspectives**:
#   - *Proponents* emphasize nuclear's crucial role in decarbonization, energy security, and innovative modular designs.
#   - *Skeptics* highlight economic challenges, high costs, regulatory hurdles, waste disposal, and public perception concerns.
# - **Expert Opinions**:
#   - *U.S.* agencies projects that private investment, technological innovation, and streamlined regulation can enable rapid deployment of SMRs.
#   - *International* partners see nuclear as essential for achieving global climate targets, especially in emerging economies.
#
# ## Future Outlook
# - **Emerging Trends**:
#   - *SMRs & Microreactors*: Accelerated licensing, cost reduction, and deployment are anticipated, with projections reaching 120 GW globally by 2050 under optimal policy support.
#   - *Advanced Reactor Technologies*: Teams are focusing on high-temperature gas reactors, fast reactors, and MSRs with promising safety, efficiency, and waste management profiles.
#   - *Fuel & Waste Management*: Progress in accident-tolerant fuels, high-assay low-enriched uranium (HALEU), and innovative waste immobilization will enhance sustainability.
# ...
# - **Deployment & Innovation**:
#   - Modular, factory-fabricated reactors with standardized, scalable designs.
#   - Fuels: TRISO, HALEU; waste: transmutation, deep repositories.
#   - AI & digital tools for real-time safety & efficiency.
# - **Global Cooperation**:
#   - Resilient, diversified supply chains.
#   - Harmonized international safety & licensing standards.
#   - Expanded non-electric applications (heat, hydrogen, water desalination).
# - **Leadership & Market Growth**:
#   - US, China, Russia uphold & grow capacities.
#   - Emerging markets rapidly diversifying.
#   - Private & public sectors working synergistically.
#
# ---
#
# ## Conclusions
# The nuclear sector is on the cusp of a transformative phase supported by innovation, policy backing, and international collaboration. Overcoming barriers—costs, licensing, societal acceptance—is critical, but strategic policies, technological advances, and supply chain diversification will unlock a pathway toward capacity over 900 GW by 2050. Nuclear power’s role in decarbonization, energy resilience, and global leadership is set to grow substantially.
#
# ---
#
# ## References & Data Sources
# - **Reports & Policy**: IAEA (2024–2026), workshops, scenario scenarios
# - **Operational Data**: World Nuclear Association (latest build & operation)
# - **Policy & Industry**: NEI, private sector investments (Amazon, Google)
# - **International Frameworks**: NEA, GIF
# - **Scientific Literature**: reactor design, fuels, waste management
# - **Private & Public Funding**: US & international initiatives
#
# **End of Report**
# ---------- TextMessage (research_agent) ----------
# # Strategic Outlook on Nuclear Energy (2023–2026)
#
# ## Executive Summary
# - **Technological Diversification & Growth**: The industry is moving beyond traditional large reactors to include over 80 designs with operational prototypes such as China’s HTR-PM (2023), Russia’s floating nuclear plant, and the US Vogtle Units 3 & 4. These advanced reactors encompass SMRs, fast reactors, MSRs, and high-temperature gas systems, progressing toward commercial use.
# - **Global Capacity & Construction**: About 416 reactors produce roughly 2,667 TWh (~9% of global electricity). Over 70 GW are under construction—in China (over 30 GW planned/in progress), Russia, the US, Africa, Asia, and Europe. Projects like China’s latest large units and SMRs, Russia’s floating plant, and US license/operation advances mark significant milestones.
# - **Policy & Investment Momentum**: Billions USD are invested, supported by policies such as the US Inflation Reduction Act, sustained Chinese capacity expansion, UK SMR strategies, and private investments from tech firms (Amazon, Google). The goal: tripling capacity by 2050.
# - **Industry & Innovation Trends**:
#   - Deployment of passive safety features, AI-enabled safety and operations, advanced fuels (TRISO, HALEU).
#   - Modular, factory-fabricated reactors significantly lower costs and build times, supporting rapid scale-up.
#   - International collaboration enhances supply chain resilience (enrichment, fuel) and safety/licensing harmonization.
# - **Barriers & Challenges**:
#   - High initial capital costs, licensing delays, fuel supply constraints (notably HALEU), waste management, societal acceptance.
#   - Geopolitical risks stemming from concentration in uranium enrichment capacities.
# - **Outlook & Scenarios (2023–2050)**:
#   - Capacity could grow to **514–950 GW**, contingent on policy & market support.
#   - SMRs might constitute **30–50%** of new capacity, potentially outpacing large reactors with enabling policies.
#   - Cost, regulation, supply chain, and waste solutions breakthroughs are critical.
#
# ---
#
# ## Recent Milestones & Projects (2023–2025)
# - **Reactors & Capacity**:
#   - ~416 reactors (~2,667 TWh/year), with +70 GW under construction globally.
#   - China’s SMR (HTR-PM) began commercial operation in 2023.
#   - Russia’s floating plant (Akademik Lomonosov) operational since 2019.
#   - US’s Vogtle Units 3 & 4 commissioned; licensing & siting ongoing for NuScale and Pele microreactors.
#   - Projects in Africa (Ghana, Rwanda), Southeast Asia, and Europe making progress.
# - **Technology & R&D**:
#   - 80+ SMR designs, 4 under early construction.
#   - Advanced reactors: helium-cooled (X-energy), fast neutron (BN-800, RITM-200), MSRs (Kairos, Terrestrial).
#   - New fuels: TRISO particles, HALEU; waste management: transmutation & deep geological repositories.
# - **Policy & Market Environment**:
#   - US’s IRA, China’s buildout, UK’s SMR strategy, and international cooperation initiatives.
#   - Private investments: Amazon, Google, utilities in MW–GW projects for data centers and industry.
# - **International & Industry Alliances**:
#   - China & Russia dominate new capacity; Europe and North America focus on life extension & SMRs.
#   - Africa & Asia seek capacity growth aligned with development and decarbonization.
# - **Funding & Development**:
#   - Billions in private & public funds for fuel infrastructure, demo projects, & licensing reforms.
#
# ---
#
# ## Industry & Policy Drivers
# | Aspect | Drivers | Challenges | Opportunities |
# |---------|----------|--------------|--------------|
# | **SMRs & Advanced Reactors** | Modularity, decarbonization, private interest | Cost, licensing, fuel supply (HALEU) | Rapid deployment, remote & industrial applications, sector decarbonization |
# | **Fuels & Waste Management** | Safety, waste minimization, proliferation resistance | Fuel scarcity, waste disposal infrastructure | TRISO, reprocessing, transmutation, deep repositories |
# | **Policy & Investment** | Climate commitments, resilience | Regulatory delays, market uncertainty | Large funding, international standards, partnerships |
# | **Supply Chain** | Uranium enrichment concentration, fuel dependence | HALEU supply limits, geopolitical risks | Diversification & new enrichment facilities (US, Europe) |
# | **Digital & Safety Tech** | AI, passive safety, real-time monitoring | Regulatory adaptation | Safer plants, AI safety & predictive tech |
#
# ---
#
# ## Future Scenarios & Outlook (2023–2050)
# | Scenario | Capacity GW | Focus | Drivers | Barriers Addressed |
# |----------|--------------|--------|---------|----------------|
# | **Baseline** | 514 GW | Existing + SMRs | Policy & tech maturation | Costs, regulation, waste |
# | **Accelerated** | 850–950 GW | Broad deployment | Tech breakthroughs, policy/support | Cost reduction, licensing, supply chain |
# | **Limited** | <514 GW | Slow growth | Policy stagnation | Costs, supply chain, societal acceptance |
#
# *Supportive policy & technological breakthroughs could enable SMRs (>120 GW) to exceed large reactors, with total capacity surpassing 900 GW by 2050.*
#
# ---
#
# ## Key Geographies & Markets
# - **China**: Leading—>30 GW under construction; targets >100 GW in 2030.
# - **US**: Licensing (NuScale), new reactors (Vogtle), microreactors (Pele); policy momentum.
# - **Europe**: UK, France, Finland are extending lifetimes, building SMRs, and investing in new large units.
# - **Africa & Asia**: Ghana, Rwanda, India, Indonesia—capacity for energy independence & decarbonization.
# - **Russia**: Continues expansion of fast reactors & floating plants.
# - **Emerging Markets**: Poland (first reactor), Mexico, Vietnam—expanding capacity for growth and climate mitigation.
#
# ---
#
# ## Barriers & Enablers
# | Barrier | Enabler |
# |------------|-----------|
# | Capital costs, licensing delays, fuel and waste supply, societal resistance | Regulatory harmonization, diversified supply, digital safety tools, international cooperation, private & public partnerships |
#
# ---
#
# ## Pathways (2023–2050)
# - **Target**: >900 GW total; SMRs >120 GW, potentially exceeding traditional large plants.
# - **Deployment**:
#   - Modular, factory-fabricated reactors.
#   - Innovative fuels: TRISO, HALEU.
#   - Waste reduction: transmutation & deep repositories.
#   - AI & digital tools for safety & efficiency.
# - **Global Strategy**:
#   - Enhance supply chain resilience (uranium, enrichment).
#   - Harmonize safety & licensing.
#   - Expand into non-electric applications: heat, hydrogen, desalination.
# - **Leadership**:
#   - Nations at the forefront: US, China, Russia, Europe.
#   - Rapid adoptions & capacity expansions in emerging economies.
#   - Private & government joint efforts.
#
# ## Conclusions
# The next decade promises a nuclear renaissance, propelled by innovations, streamlined policies, and international cooperation. Overcoming costs, regulation, and societal barriers will unlock capacity beyond 900 GW by 2050, cementing nuclear’s critical role in climate mitigation and energy security.
#
# ---
#
# ## References & Data Sources
# - IAEA (2024–2026 reports, workshops)
# - OECD IEA outlooks & scenarios
# - World Nuclear Association latest data
# - NEI & industry policy updates
# - Private sector investments (Amazon, Google)
# - International frameworks (NEA, GIF)
# - Scientific literature on reactor & fuel innovations
#
# **End of report**
# ---------- TextMessage (research_planner) ----------
# # Strategic Outlook on Nuclear Energy (2023–2026)
#
# ## Executive Summary
# - **Technological Diversification & Innovation**: The sector is rapidly evolving, with over 80 advanced reactor designs progressing toward commercial deployment. Notable milestones include China’s HTR-PM (2023), Russia’s floating nuclear plant, and the US Vogtle Units 3 & 4 now operational.
# - **Global Capacity & Construction**: Approximately 416 reactors generate around 2,667 TWh (~9% of global electricity). Over 70 GW are under construction, chiefly driven by China (>30 GW planned/in progress), with substantial projects in Russia, the US, Africa, Asia, and Europe.
# - **Policy & Investment Acceleration**: Billions USD are committed through government policies such as the US Inflation Reduction Act, China’s relentless expansion, UK’s SMR programs, and private sector investments (Amazon, Google). The goal: triple global capacity by 2050.
# - **Emerging Industry & Tech Trends**:
#   - Deployment of passive safety, AI-enabled safety and performance monitoring, and advanced fuels (TRISO, HALEU).
#   - Modular, factory-built reactors drastically reduce costs and build times, enabling rapid scaling.
#   - International cooperation enhances supply chain resilience (enrichment, fuel) and harmonizes safety standards and licensing.
# - **Challenges & Barriers**:
#   - High initial capital costs, licensing delays, fuel supply (notably HALEU), waste management, societal acceptance.
#   - Geopolitical risks due to concentration in uranium enrichment & fuel supply capacities.
# - **Outlook & Scenarios (2023–2050)**:
#   - Reactor capacity could reach **514–950 GW** depending on policy environment.
#   - SMRs may provide **30–50%** of new capacity, potentially surpassing large reactors under favorable policy/support.
#   - Technological breakthroughs and regulatory reforms are critical.
#
# ---
#
# ## Milestones & Recent Developments (2023–2025)
# - **Reactors & Capacity**:
#   - ~416 reactors (~2,667 TWh/year), with >70 GW under construction.
#   - China’s SMR (HTR-PM) operational since 2023.
#   - Russia’s floating plant (Akademik Lomonosov) launched in 2019.
#   - US: Vogtle Units 3 & 4 commissioned; licensing ongoing for NuScale and Pele microreactors.
#   - Projects in Africa (Ghana, Rwanda), Southeast Asia, and Europe making progress.
# - **Technology & R&D**:
#   - 80+ SMR designs; 4 under early construction/licensing.
#   - Advanced reactors: helium-cooled (X-energy), fast neutron (BN-800, RITM-200), MSRs (Kairos, Terrestrial).
#   - New fuels: TRISO particles, HALEU; waste solutions: transmutation & deep repositories.
# - **Policy & Market Environment**:
#   - US’s IRA, China’s buildout, UK’s SMR strategy, and international cooperation.
#   - Private investments: Amazon, Google, utilities supporting MW–GW projects.
# - **International & Industry Alliances**:
#   - China & Russia dominate capacity growth; Europe & North America focus on life extensions & SMRs.
#   - Africa & Asia pursue capacity to meet development needs.
# - **Funding & Development**:
#   - Governments and private sector investing billions in fuel infrastructure, demonstration projects, and licensing reforms.
#
# ---
#
# ## Industry & Policy Drivers
# | Aspect | Drivers | Challenges | Opportunities |
# |---------|----------|--------------|--------------|
# | **SMRs & Advanced Reactors** | Modular design, decarbonization, private market interest | Cost, licensing, fuel supply (HALEU) | Rapid deployment, remote & industrial applications, hybrid systems |
# | **Fuels & Waste** | Safety, waste reduction, proliferation resistance | Fuel supply (HALEU), waste disposal infrastructure | TRISO, reprocessing, transmutation, deep repositories |
# | **Policy & Investment** | Climate commitments, energy security | Licensing delays, market uncertainty | Public/private funding, international standards |
# | **Supply Chain** | Enrichment capacity concentration, dependence on limited sources | HALEU scarcity, geopolitical risks | Diversification, new enrichment facilities (U.S., Europe) |
# | **Digital & Safety Technologies** | AI, passive safety, real-time monitoring | Regulatory adaptation | Safer plants, AI monitoring, predictive analytics |
#
# ---
#
# ## Outlook & Scenarios (2023–2050)
# | Scenario | Capacity GW | Focus | Drivers | Barriers Addressed |
# |----------|--------------|--------|---------|----------------|
# | **Baseline** | 514 GW | Existing + SMRs | Policy support, tech standardization | Cost, regulation, waste management |
# | **Accelerated** | 850–950 GW | Wide deployment | Tech breakthroughs, policies, finance | Cost reduction, licensing, supply chain |
# | **Limited** | <514 GW | Slow growth | Policy stagnation, delays | Costs, supply, societal acceptance |
#
# *Supportive policies and technological breakthroughs can enable SMRs >120 GW, exceeding 900 GW in total capacity by 2050.*
#
# ---
#
# ## Primary Markets & Geographical Trends
# - **China**: Largest in buildout (>30 GW underway); targeted >100 GW by 2030.
# - **US**: Licensing (NuScale, Pele), new plants (Vogtle), microreactors.
# - **Europe**: UK, France, Finland expanding through operational life extensions and SMRs.
# - **Africa & Asia**: Ghana, Rwanda, India, Indonesia expanding capacity for energy & water security.
# - **Russia**: Continuing to expand fast reactors, floating plants.
# - **Emerging Countries**: Poland (first reactor), Mexico, Vietnam, exploring capacity build-outs.
#
# ---
#
# ## Barriers & Enablers
# | Barrier | Enabler |
# |------------|-----------|
# | Capital costs, licensing delays, fuel supply (HALEU), waste disposal, societal resistance | Regulatory harmonization, diversified fuel supply, digital safety systems, international cooperation, private & public partnerships |
#
# ---
#
# ## Pathways (2023–2050)
# - **Capacity Goal**: >900 GW; SMRs >120 GW, potentially surpassing conventional large reactors.
# - **Deployment & Innovation**:
#   - Modular, factory-fabricated reactors.
#   - Advanced fuels: TRISO, HALEU.
#   - Waste: transmutation, geological repositories.
#   - Digital & AI tools for safety, operations, monitoring.
# - **Global Cooperation**:
#   - Supply chain resilience (uranium, enrichment).
#   - Harmonization of safety & licensing standards.
#   - Non-electric uses: heat, hydrogen, desalination.
# - **Leadership & Market Development**:
#   - US, China, Russia sustain core capacity.
#   - Emerging markets rapidly expanding.
#   - Private & government collaboration critical.
#
# ## Conclusions
# The next decade is poised for a nuclear renaissance driven by innovation, policy support, and international cooperation. Overcoming costs, licensing, waste, and societal barriers is essential, but concerted efforts can lead to capacity exceeding 900 GW by 2050—securing nuclear’s role in climate mitigation and energy security.
#
# ## References & Data Sources
# - IAEA (2024–2026 reports, workshops)
# - OECD IEA scenarios & outlooks
# - World Nuclear Association latest capacity & build data
# - NEI and private sector commitments (Amazon, Google)
# - International frameworks (NEA, GIF)
# - Scientific literature on reactor innovations, fuels, waste management
#
# **End of report**
