# %%
import requests

BASE_URL = "http://127.0.0.1:8000"
APP_NAME = "travel_advisor_agent"
USER_ID = "u_123"
SESSION_ID = "62382353-84e4-4932-9a11-77836dbddff9"

# %%
response = requests.post(f"{BASE_URL}/apps/{APP_NAME}/users/{USER_ID}/sessions")

print(response.json())
# Out:
# {'id': '62382353-84e4-4932-9a11-77836dbddff9', 'appName': 'travel_advisor_agent', 'userId': 'u_123', 'state': {}, 'events': [], 'lastUpdateTime': 1781844726.769832}

# %%
message = {
    "appName": APP_NAME,
    "userId": USER_ID,
    "sessionId": SESSION_ID,
    "newMessage": {
        "parts": [{"text": "I want to go to Tokyo"}],
        "role": "user",
    },
}

response = requests.post(f"{BASE_URL}/run", json=message)
# Out:
# [{'modelVersion': 'gpt-4o-2024-08-06', 'content': {'parts': [{'functionCall': {'id': 'call_roJz2MIy5nLtplxUJCt1wo6y', 'args': {'location': 'Tokyo'}, 'name': 'get_weather'}}, {'functionCall': {'id': 'call_kD1Vs3oGe6JHHRO8zLmEm7r6', 'args': {'location': 'Tokyo'}, 'name': 'get_local_attractions'}}], 'role': 'model'}, 'partial': False, 'finishReason': 'STOP', 'usageMetadata': {'cachedContentTokenCount': 0, 'candidatesTokenCount': 46, 'promptTokenCount': 408, 'totalTokenCount': 454}, 'invocationId': 'e-6c73ab10-7c56-4c00-b6c8-154280210094', 'author': 'TravelAdvisorAgent', 'actions': {'stateDelta': {}, 'artifactDelta': {}, 'requestedAuthConfigs': {}, 'requestedToolConfirmations': {}}, 'nodeInfo': {'path': 'TravelAdvisorAgent@1'}, 'longRunningToolIds': [], 'id': '394efdbb-6ea2-4b52-8295-699b4f888052', 'timestamp': 1781845150.671912}, {'content': {'parts': [{'functionResponse': {'id': 'call_roJz2MIy5nLtplxUJCt1wo6y', 'name': 'get_weather', 'response': {'location': 'Tokyo', 'temperature': '22°C', 'condition': 'Partly cloudy', 'humidity': '65%', 'wind': '12 km/h', 'forecast': 'Mild weather with occasional clouds expected throughout the day'}}}, {'functionResponse': {'id': 'call_kD1Vs3oGe6JHHRO8zLmEm7r6', 'name': 'get_local_attractions', 'response': {'location': 'Tokyo', 'category': 'all', 'attractions': [{'name': 'Tokyo Tower', 'type': 'landmark', 'rating': 4.5, 'description': 'Communications and observation tower'}, {'name': 'Senso-ji', 'type': 'temple', 'rating': 4.6, 'description': 'Ancient Buddhist temple'}, {'name': 'Shibuya Crossing', 'type': 'landmark', 'rating': 4.4, 'description': 'Busiest pedestrian crossing'}, {'name': 'Meiji Shrine', 'type': 'shrine', 'rating': 4.7, 'description': 'Shinto shrine dedicated to Emperor Meiji'}, {'name': 'Tokyo Skytree', 'type': 'tower', 'rating': 4.6, 'description': 'Broadcasting and observation tower'}], 'total_count': 5}}}], 'role': 'user'}, 'invocationId': 'e-6c73ab10-7c56-4c00-b6c8-154280210094', 'author': 'TravelAdvisorAgent', 'actions': {'stateDelta': {}, 'artifactDelta': {}, 'requestedAuthConfigs': {}, 'requestedToolConfirmations': {}}, 'nodeInfo': {'path': 'TravelAdvisorAgent@1'}, 'id': '742afc75-6735-4898-bf66-9a6df928944d', 'timestamp': 1781845153.618326}, {'modelVersion': 'gpt-4o-2024-08-06', 'content': {'parts': [{'text': "Tokyo is an exciting city to visit! Here's some helpful information for your trip:\n\n### Current Weather in Tokyo:\n- **Temperature:** 22°C\n- **Condition:** Partly cloudy\n- **Humidity:** 65%\n- **Wind:** 12 km/h\n- **Forecast:** Mild weather with occasional clouds expected throughout the day\n\n### Must-See Attractions in Tokyo:\n1. **Tokyo Tower** - A communications and observation tower with a rating of 4.5. It's iconic and offers great views of the city.\n2. **Senso-ji** - An ancient Buddhist temple with a rating of 4.6, located in the Asakusa district. It's Tokyo's oldest temple and very popular among tourists.\n3. **Shibuya Crossing** - Known as the busiest pedestrian crossing in the world, with a rating of 4.4. It's a quintessential Tokyo experience.\n4. **Meiji Shrine** - A Shinto shrine dedicated to Emperor Meiji, with a rating of 4.7. It's located in a beautiful forested area.\n5. **Tokyo Skytree** - A broadcasting and observation tower with a rating of 4.6. It offers spectacular panoramic views of Tokyo.\n\nThese attractions offer a fantastic mix of cultural experiences and iconic landmarks. Enjoy your visit to Tokyo! If you need more information or assistance with anything else, feel free to ask."}], 'role': 'model'}, 'partial': False, 'finishReason': 'STOP', 'usageMetadata': {'cachedContentTokenCount': 0, 'candidatesTokenCount': 285, 'promptTokenCount': 707, 'totalTokenCount': 992}, 'invocationId': 'e-6c73ab10-7c56-4c00-b6c8-154280210094', 'author': 'TravelAdvisorAgent', 'actions': {'stateDelta': {}, 'artifactDelta': {}, 'requestedAuthConfigs': {}, 'requestedToolConfirmations': {}}, 'nodeInfo': {'path': 'TravelAdvisorAgent@1'}, 'id': '1b53deec-c300- ...

# %%
data = response.json()

for event in data:
    content = event.get("content")
    parts = content.get("parts")
    for part in parts:
        function_call = part.get("functionCall", None)
        if function_call:
            print(function_call.get("name"))
        text = part.get("text", None)
        if text:
            print(text)
    print("=" * 60)
# Out:
# get_weather
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# get_local_attractions
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
# Tokyo is an exciting city to visit! Here's some helpful information for your trip:
#
# ### Current Weather in Tokyo:
# - **Temperature:** 22°C
# - **Condition:** Partly cloudy
# - **Humidity:** 65%
# - **Wind:** 12 km/h
# - **Forecast:** Mild weather with occasional clouds expected throughout the day
#
# ### Must-See Attractions in Tokyo:
# 1. **Tokyo Tower** - A communications and observation tower with a rating of 4.5. It's iconic and offers great views of the city.
# 2. **Senso-ji** - An ancient Buddhist temple with a rating of 4.6, located in the Asakusa district. It's Tokyo's oldest temple and very popular among tourists.
# 3. **Shibuya Crossing** - Known as the busiest pedestrian crossing in the world, with a rating of 4.4. It's a quintessential Tokyo experience.
# 4. **Meiji Shrine** - A Shinto shrine dedicated to Emperor Meiji, with a rating of 4.7. It's located in a beautiful forested area.
# 5. **Tokyo Skytree** - A broadcasting and observation tower with a rating of 4.6. It offers spectacular panoramic views of Tokyo.
#
# These attractions offer a fantastic mix of cultural experiences and iconic landmarks. Enjoy your visit to Tokyo! If you need more information or assistance with anything else, feel free to ask.
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
